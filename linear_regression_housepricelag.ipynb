# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib

# %%
df = pd.read_csv("homepriceslag.csv", sep='\t')
df.head()
# Out:
#    Area      Price
# 0   800   45000000
# 1  1200   68000000
# 2  1500   90000000
# 3  2000  120000000
# 4  1000   55000000

# %%
plt.xlabel('Area(sqr ft)')
plt.ylabel('Price(Million NGN)')
plt.scatter(df.Area, df.Price, color = 'black', marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
joblib.dump(reg, "lagprice_model.pkl")
# Out:
# ['lagprice_model.pkl']
