# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import joblib

# %%
df = pd.read_csv("homepricesmaid.csv")
df.head()
# Out:
#    Area     Price
# 0   600  32000000
# 1   800  40000000
# 2  1000  50000000
# 3  1200  60000000
# 4  1500  75000000

# %%
plt.xlabel('Area(sqr ft)')
plt.ylabel('Price(Million NGN)')
plt.scatter(df.Area, df.Price, color = 'black', marker='+')

# %%
reg = LinearRegression()
reg.fit(df[['Area']], df.Price)
# Out:
# LinearRegression()

# %%
joblib.dump(reg, "price_model.pkl")
# Out:
# ['price_model.pkl']
